# %% [markdown]
# 分類（オーバーサンプリング）→回帰

# %% [markdown]
# ## 必要なライブラリのimport

# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
import pickle

# %%
# 予測したいデータの読み込み
path_test_preprp = '../../../../data/processed/test_processed_20.csv'

test = pd.read_csv(path_test_preprp)
#del test['target']

# %% [markdown]
# ## 保存されたモデルを使って予測を行う

# %%
n_folds = 5
predictions_cls = np.zeros(len(test))
features = [c for c in test.columns if c not in ['card_id',]]


for fold_ in range(n_folds):
    # モデルを読み込む
    with open(f'../src/models/lgb_21_cls/model_fold_{fold_}.pkl', 'rb') as f:
        clf = pickle.load(f)
    # モデルで予測を行う
    fold_predictions = clf.predict(test[features])
    # 予測結果を足し合わせる
    predictions_cls += fold_predictions

# 平均を取る
predictions_cls /= n_folds

# RMSEを計算する（テストデータに対して真の値がある場合）
# y_testが存在する場合に限り
if 'y_test' in locals():
    score = mean_squared_error(y_test, predictions_cls, squared=False)
    print(f'RMSE={score}')

# %%
print(len(predictions_cls[predictions_cls<0.5]))
print(predictions_cls.min())

# 予測結果を出力する
print(predictions_cls)
# Out:
# 1618
# 0.01190011636168022
# [0.95241413 0.99947085 0.99742197 ... 0.89454147 0.94694344 0.99877014]

# %%
predictions_cls_done = np.where(predictions_cls < 0.5, -33.21928095, 1)

# %%
tmp_cls = pd.DataFrame({"card_id":test["card_id"].values})
tmp_cls["target"] = predictions_cls_done
tmp_cls
# Out:
#                 card_id  target
# 0       C_ID_0ab67a22ab     1.0
# 1       C_ID_130fd0cbdd     1.0
# 2       C_ID_b709037bc5     1.0
# 3       C_ID_d27d835a9f     1.0
# 4       C_ID_2b5e3df5c2     1.0
# ...                 ...     ...
# 123618  C_ID_7a239d2eda     1.0
# 123619  C_ID_75ace375ae     1.0
# 123620  C_ID_21d56d950c     1.0
# 123621  C_ID_6c46fc5a9d     1.0
# 123622  C_ID_87e7979a5f     1.0
#
# [123623 rows x 2 columns]

# %%
test_reg = test[test.card_id.isin(tmp_cls[tmp_cls.target==1].card_id)].reset_index(drop=True)

# %%
test_reg
# Out:
#         first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0                     1978  C_ID_0ab67a22ab          3          3          1
# 1                     1888  C_ID_130fd0cbdd          2          3          0
# 2                     2100  C_ID_b709037bc5          5          1          1
# 3                     2222  C_ID_d27d835a9f          2          1          0
# 4                     1491  C_ID_2b5e3df5c2          5          1          1
# ...                    ...              ...        ...        ...        ...
# 122000                2161  C_ID_7a239d2eda          2          2          0
# 122001                2131  C_ID_75ace375ae          3          1          1
# 122002                1766  C_ID_21d56d950c          5          1          1
# 122003                2039  C_ID_6c46fc5a9d          2          1          0
# 122004                1796  C_ID_87e7979a5f          5          1          1
#
#         elapsed_time  hist_frequency  hist_amount_total  hist_amount_mean  \
# 0                306              68         -40.733734         -0.599025
# 1                396              78         -49.136513         -0.629955
# 2                184              13           4.528841          0.348372
# 3                 62              26         -13.690715         -0.526566
# 4                793             110          25.139385          0.228540
# ...              ...             ...                ...               ...
# 122000           123              73         -49.404780         -0.676778
# 122001           153               7          -4.914616         -0.702088
# 122002           518              37          -6.583716         -0.177938
# 122003           245              62         -39.123627         -0.631026
# 122004           488              42         -25.314203         -0.602719
#
#         hist_amount_max  ...  total_month_lag_max  total_month_lag_min  \
# 0              0.235676  ...                    2                   -8
# 1              0.318817  ...                    2                  -13
# 2              2.525866  ...                    1                   -6
# 3              0.087965  ...                    2                   -2
# 4             15.782255  ...                    2                  -13
# ...                 ...  ...                  ...                  ...
# 122000        -0.525387  ...                    0                   -4
# 122001        -0.578911  ...                    2                   -5
# 122002         1.664306  ...                    0                  -10
# 122003        -0.115794  ...                    1                   -4
# 122004         0.470089  ...                    1                  -13
#
#         total_month_lag_median  total_category_1_mod  total_category_2_mod  \
# 0                         -3.0                     0                   1.0
# 1                        -10.0                     0                   4.0
# 2                         -2.0                     0                   5.0
# 3                          0.0                     0                   1.0
# 4                         -6.0                     0                   4.0
# ...                        ...                   ...                   ...
# 122000                    -2.0                     0                   1.0
# 122001                    -2.0                     0                   1.0
# 122002                    -5.0                     0                   5.0
# 122003                    -2.0                     0                   3.0
# 122004                    -6.0                     0                   1.0
#
#         total_category_3_mod  total_duration  ratio_amount_total  \
# 0                        2.0             330            0.043633
# 1                        2.0             462            0.120976
# 2                        3.0             199            0.039676
# 3                        2.0             134            0.419583
# 4                        2.0             464            0.479980
# ...                      ...             ...                 ...
# 122000                   1.0             134                 NaN
# 122001                   1.0             206            0.540877
# 122002                   2.0             305                 NaN
# 122003                   3.0             177            0.096611
# 122004                   2.0             422            0.019713
#
#         ratio_amount_mean  ratio_merchant_category_nu
# 0                0.989020                    0.187500
# 1                1.048458                    0.500000
# 2                0.257896                    0.250000
# 3                1.090915                    0.555556
# 4                8.799636                    0.161290
# ...                   ...                         ...
# 122000                NaN                         NaN
# 122001           0.946535                    1.000000
# 122002                NaN                         NaN
# 122003           0.998317                    0.333333
# 122004           0.827954                    0.083333
#
# [122005 rows x 94 columns]

# %%
n_folds = 5
predictions = np.zeros(len(test_reg))
features = [c for c in test_reg.columns if c not in ['card_id',]]
#categorical_feats = ['feature_1','feature_2', 'feature_3','hist_merchant_category_nu','hist_merchant_category_mode','hist_city_nu','hist_city_mode','hist_state_nu','hist_state_mode','hist_category_1_mod','hist_category_2_mod','hist_category_3_mod','new_merchant_category_nu','new_merchant_category_mode','new_city_nu','new_city_mode','new_state_nu','new_state_mode','new_category_1_mod','new_category_2_mod','new_category_3_mod']


for fold_ in range(n_folds):
    # モデルを読み込む
    with open(f'../src/models/lgb_21_reg/model_fold_{fold_}.pkl', 'rb') as f:
        clf = pickle.load(f)
    # モデルで予測を行う
    fold_predictions = clf.predict(test_reg[features])
    # 予測結果を足し合わせる
    predictions += fold_predictions

# 平均を取る
predictions /= n_folds

# RMSEを計算する（テストデータに対して真の値がある場合）
# y_testが存在する場合に限り
if 'y_test' in locals():
    score = mean_squared_error(y_test, predictions, squared=False)
    print(f'RMSE={score}')

# %%
# 予測結果を出力する
print(predictions)
# Out:
# [-0.10077957  0.02924514  0.63447003 ...  0.94123341 -0.6613987
#   0.26516787]

# %%
tmp_reg = pd.DataFrame({"card_id":test_reg["card_id"].values})
tmp_reg["target"] = predictions
tmp_reg
sub = pd.merge(tmp_cls,tmp_reg,how='left',on='card_id',suffixes=('_left', '_right'))
sub['target'] = sub['target_right'].combine_first(sub['target_left'])

# 不要な列を削除
sub= sub.drop(columns=['target_left', 'target_right'])
sub[sub.target  >0]
# Out:
#                 card_id    target
# 5       C_ID_5814b4f13c  0.419815
# 6       C_ID_a1b3c75277  0.229288
# 7       C_ID_f7cada36d3  0.949763
# 11      C_ID_0e281e8ad6  0.041345
# 12      C_ID_8375dfdaa2  0.028700
# ...                 ...       ...
# 123616  C_ID_107d93e20c  1.331442
# 123617  C_ID_0e74bd4966  0.480041
# 123618  C_ID_7a239d2eda  0.973505
# 123620  C_ID_21d56d950c  1.001798
# 123622  C_ID_87e7979a5f  0.060479
#
# [52799 rows x 2 columns]

# %%
sub
# Out:
#                 card_id    target
# 0       C_ID_0ab67a22ab -0.157102
# 1       C_ID_130fd0cbdd -0.223990
# 2       C_ID_b709037bc5 -0.407277
# 3       C_ID_d27d835a9f -0.065234
# 4       C_ID_2b5e3df5c2 -0.924936
# ...                 ...       ...
# 123618  C_ID_7a239d2eda  0.973505
# 123619  C_ID_75ace375ae -0.208551
# 123620  C_ID_21d56d950c  1.001798
# 123621  C_ID_6c46fc5a9d -0.791592
# 123622  C_ID_87e7979a5f  0.060479
#
# [123623 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.hist(sub.target,bins=100)
# Out:
# (array([1.6180e+03, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 4.0000e+00, 6.0000e+00, 4.5000e+01, 1.7200e+02,
#         6.2400e+02, 1.9080e+03, 5.3000e+03, 1.3002e+04, 2.5784e+04,
#         3.2709e+04, 1.8488e+04, 1.1774e+04, 7.7290e+03, 3.0640e+03,
#         1.0240e+03, 2.5900e+02, 7.5000e+01, 3.0000e+01, 8.0000e+00]),
#  array([-33.21928095, -32.85281758, -32.48635421, -32.11989085,
#         -31.75342748, -31.38696411, -31.02050074, -30.65403738,
#         -30.28757401, -29.92111064, -29.55464727, -29.18818391,
#         -28.82172054, -28.45525717, -28.0887938 , -27.72233044,
#         -27.35586707, -26.9894037 , -26.62294033, -26.25647696,
#         -25.8900136 , -25.52355023, -25.15708686, -24.79062349,
#         -24.42416013, -24.05769676, -23.69123339, -23.32477002,
#         -22.95830666, -22.59184329, -22.22537992, -21.85891655,
#         -21.49245319, -21.12598982, -20.75952645, -20.39306308,
#         -20.02659972, -19.66013635, -19.29367298, -18.92720961,
#         -18.56074624, -18.19428288, -17.82781951, -17.46135614,
#         -17.09489277, -16.72842941, -16.36196604, -15.99550267,
#         -15.6290393 , -15.26257594, -14.89611257, -14.5296492 ,
#         -14.16318583, -13.79672247, -13.4302591 , -13.06379573,
#         -12.69733236, -12.33086899, -11.96440563, -11.59794226,
#         -11.23147889, -10.86501552, -10.49855216, -10.13208879,
#          -9.76562542,  -9.39916205,  -9.03269869,  -8.66623532,
#          -8.29977195,  -7.93330858,  -7.56684522,  -7.20038185,
#          -6.83391848,  -6.46745511,  -6.10099175,  -5.73452838,
#          -5.36806501,  -5.00160164,  -4.63513827,  -4.26867491,
#          -3.90221154,  -3.53574817,  -3.1692848 ,  -2.80282144,
#          -2.43635807,  -2.0698947 ,  -1.70343133,  -1.33696797,
#          -0.9705046 ,  -0.60404123,  -0.23757786,   0.1288855 ,
#           0.49534887,   0.86181224,   1.22827561,   1.59473898,
#           1.96120234,   2.32766571,   2.69412908,   3.06059245,
#           3.42705581]),
#  <BarContainer object of 100 artists>)

# %% [markdown]
# ## 提出用ファイルの作成

# %%
sub.to_csv("../submit_oshikiri_21.csv", index=False)
