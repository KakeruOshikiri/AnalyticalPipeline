# %% [markdown]
# 谷口特徴量を全部追加

# %% [markdown]
# ## 必要なライブラリのimport

# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
import pickle

# %%
# 予測したいデータの読み込み

path_test = '../../../../data/extornal/test_processed_clv&churn.csv'

test = pd.read_csv(path_test)

# %%
test
# Out:
#         first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0                     1978  C_ID_0ab67a22ab          3          3          1
# 1                     1888  C_ID_130fd0cbdd          2          3          0
# 2                     2100  C_ID_b709037bc5          5          1          1
# 3                     2222  C_ID_d27d835a9f          2          1          0
# 4                     1491  C_ID_2b5e3df5c2          5          1          1
# ...                    ...              ...        ...        ...        ...
# 123618                2161  C_ID_7a239d2eda          2          2          0
# 123619                2131  C_ID_75ace375ae          3          1          1
# 123620                1766  C_ID_21d56d950c          5          1          1
# 123621                2039  C_ID_6c46fc5a9d          2          1          0
# 123622                1796  C_ID_87e7979a5f          5          1          1
#
#         elapsed_time  quarter  days_feature1  days_feature2  days_feature3  \
# 0                306        2            918            918            306
# 1                396        1            792           1188              0
# 2                184        3            920            184            184
# 3                 62        4            124             62              0
# 4                793        4           3965            793            793
# ...              ...      ...            ...            ...            ...
# 123618           123        4            246            246              0
# 123619           153        3            459            153            153
# 123620           518        3           2590            518            518
# 123621           245        2            490            245              0
# 123622           488        4           2440            488            488
#
#         ...  total_frequency_rfm  total_recency_rfm  total_T_rfm  \
# 0       ...                 42.0              330.0        391.0
# 1       ...                 65.0              462.0        472.0
# 2       ...                  8.0              200.0        248.0
# 3       ...                 20.0              134.0        147.0
# 4       ...                 74.0              464.0        482.0
# ...     ...                  ...                ...          ...
# 123618  ...                 46.0              135.0        203.0
# 123619  ...                  9.0              207.0        219.0
# 123620  ...                 22.0              306.0        378.0
# 123621  ...                 36.0              178.0        333.0
# 123622  ...                 39.0              423.0        478.0
#
#         total_monetary_value  total_predicted_purchases  \
# 0                  14.000505               4.835345e-01
# 1                  11.222704               1.649653e+00
# 2                  18.829160               3.937458e-01
# 3                  14.547035               1.612618e+00
# 4                  13.288375               1.820993e+00
# ...                      ...                        ...
# 123618             12.755264               1.859753e-05
# 123619              8.604392               5.134418e-01
# 123620             16.517017               5.527305e-01
# 123621             15.932347               1.291537e-07
# 123622              9.164823               8.422543e-01
#
#         total_predicted_monetary_value   total_clv  new_predicted_churn  \
# 0                            14.550096  194.320362                  1.0
# 1                            11.505040  525.640587                  0.0
# 2                            23.441234  252.455060                  1.0
# 3                            15.798126  690.123914                  0.0
# 4                            13.579936  685.082876                  0.0
# ...                                ...         ...                  ...
# 123618                       13.211865    0.006709                  NaN
# 123619                       10.463723  146.618757                  0.0
# 123620                       17.795423  271.435382                  NaN
# 123621                       16.664801    0.000059                  1.0
# 123622                        9.557810  222.952686                  1.0
#
#         hist_predicted_churn  total_predicted_churn
# 0                          1                      1
# 1                          0                      0
# 2                          0                      1
# 3                          0                      0
# 4                          0                      0
# ...                      ...                    ...
# 123618                     0                      1
# 123619                     1                      0
# 123620                     0                      1
# 123621                     1                      1
# 123622                     0                      1
#
# [123623 rows x 332 columns]

# %% [markdown]
# ## 保存されたモデルを使って予測を行う

# %%
n_folds = 5
predictions = np.zeros(len(test))
features = [c for c in test.columns if c not in ['card_id',]]
#categorical_feats = ['feature_1','feature_2', 'feature_3','hist_merchant_category_nu','hist_merchant_category_mode','hist_city_nu','hist_city_mode','hist_state_nu','hist_state_mode','hist_category_1_mod','hist_category_2_mod','hist_category_3_mod','new_merchant_category_nu','new_merchant_category_mode','new_city_nu','new_city_mode','new_state_nu','new_state_mode','new_category_1_mod','new_category_2_mod','new_category_3_mod']


for fold_ in range(n_folds):
    # モデルを読み込む
    with open(f'../src/models/lgb_52/model_fold_{fold_}.pkl', 'rb') as f:
        clf = pickle.load(f)
    # モデルで予測を行う
    fold_predictions = clf.predict(test[features])
    # 予測結果を足し合わせる
    predictions += fold_predictions

# 平均を取る
predictions /= n_folds

# RMSEを計算する（テストデータに対して真の値がある場合）
# y_testが存在する場合に限り
if 'y_test' in locals():
    score = mean_squared_error(y_test, predictions, squared=False)
    print(f'RMSE={score}')

# %%
# 予測結果を出力する
print(predictions)
# Out:
# [-3.76479979 -0.3457893  -1.31809771 ...  0.86769852 -4.37936396
#   0.12212817]

# %% [markdown]
# ## 提出用ファイルの作成

# %%
sub_df = pd.DataFrame({"card_id":test["card_id"].values})
sub_df["target"] = predictions
sub_df.to_csv("../submit_oshikiri_52.csv", index=False)

# %%
import matplotlib.pyplot as plt
#plt.yscale('log')
plt.hist(sub_df.target, bins=100)
#plt.hist(predictions[predictions<0], bins=100)
# Out:
# (array([2.0000e+00, 0.0000e+00, 1.0000e+00, 3.0000e+00, 1.0000e+00,
#         3.0000e+00, 2.0000e+00, 2.0000e+00, 0.0000e+00, 2.0000e+00,
#         2.0000e+00, 3.0000e+00, 4.0000e+00, 0.0000e+00, 4.0000e+00,
#         1.0000e+01, 5.0000e+00, 3.0000e+00, 8.0000e+00, 1.0000e+01,
#         1.2000e+01, 1.4000e+01, 1.4000e+01, 1.0000e+01, 8.0000e+00,
#         1.1000e+01, 1.8000e+01, 7.0000e+00, 1.9000e+01, 9.0000e+00,
#         2.3000e+01, 1.5000e+01, 1.5000e+01, 1.9000e+01, 2.0000e+01,
#         2.7000e+01, 2.1000e+01, 3.1000e+01, 2.2000e+01, 2.8000e+01,
#         3.0000e+01, 3.1000e+01, 4.0000e+01, 3.4000e+01, 3.1000e+01,
#         3.4000e+01, 4.1000e+01, 3.3000e+01, 4.6000e+01, 4.7000e+01,
#         6.3000e+01, 7.5000e+01, 6.1000e+01, 6.8000e+01, 9.0000e+01,
#         9.2000e+01, 9.6000e+01, 1.0700e+02, 1.2400e+02, 1.3200e+02,
#         1.6200e+02, 2.0200e+02, 2.2600e+02, 2.4400e+02, 2.9400e+02,
#         3.4900e+02, 4.6800e+02, 5.1300e+02, 6.6000e+02, 7.4200e+02,
#         9.4300e+02, 1.1800e+03, 1.5890e+03, 1.9680e+03, 2.4550e+03,
#         3.2430e+03, 4.3710e+03, 5.7150e+03, 8.1320e+03, 1.1873e+04,
#         1.7223e+04, 1.8845e+04, 1.3142e+04, 8.5880e+03, 6.4690e+03,
#         5.2270e+03, 3.4640e+03, 1.8390e+03, 8.7700e+02, 4.5300e+02,
#         2.2200e+02, 1.2800e+02, 6.2000e+01, 3.2000e+01, 2.1000e+01,
#         8.0000e+00, 7.0000e+00, 0.0000e+00, 3.0000e+00, 1.0000e+00]),
#  array([-16.27871348, -16.07981758, -15.88092167, -15.68202577,
#         -15.48312987, -15.28423397, -15.08533807, -14.88644217,
#         -14.68754627, -14.48865037, -14.28975446, -14.09085856,
#         -13.89196266, -13.69306676, -13.49417086, -13.29527496,
#         -13.09637906, -12.89748316, -12.69858725, -12.49969135,
#         -12.30079545, -12.10189955, -11.90300365, -11.70410775,
#         -11.50521185, -11.30631594, -11.10742004, -10.90852414,
#         -10.70962824, -10.51073234, -10.31183644, -10.11294054,
#          -9.91404464,  -9.71514873,  -9.51625283,  -9.31735693,
#          -9.11846103,  -8.91956513,  -8.72066923,  -8.52177333,
#          -8.32287743,  -8.12398152,  -7.92508562,  -7.72618972,
#          -7.52729382,  -7.32839792,  -7.12950202,  -6.93060612,
#          -6.73171022,  -6.53281431,  -6.33391841,  -6.13502251,
#          -5.93612661,  -5.73723071,  -5.53833481,  -5.33943891,
#          -5.14054301,  -4.9416471 ,  -4.7427512 ,  -4.5438553 ,
#          -4.3449594 ,  -4.1460635 ,  -3.9471676 ,  -3.7482717 ,
#          -3.54937579,  -3.35047989,  -3.15158399,  -2.95268809,
#          -2.75379219,  -2.55489629,  -2.35600039,  -2.15710449,
#          -1.95820858,  -1.75931268,  -1.56041678,  -1.36152088,
#          -1.16262498,  -0.96372908,  -0.76483318,  -0.56593728,
#          -0.36704137,  -0.16814547,   0.03075043,   0.22964633,
#           0.42854223,   0.62743813,   0.82633403,   1.02522993,
#           1.22412584,   1.42302174,   1.62191764,   1.82081354,
#           2.01970944,   2.21860534,   2.41750124,   2.61639714,
#           2.81529305,   3.01418895,   3.21308485,   3.41198075,
#           3.61087665]),
#  <BarContainer object of 100 artists>)

# %%
sub_df
# Out:
#                 card_id    target
# 0       C_ID_0ab67a22ab -2.072153
# 1       C_ID_130fd0cbdd -0.191818
# 2       C_ID_b709037bc5 -0.591274
# 3       C_ID_d27d835a9f -0.176060
# 4       C_ID_2b5e3df5c2 -0.980048
# ...                 ...       ...
# 123618  C_ID_7a239d2eda  0.800503
# 123619  C_ID_75ace375ae -0.307557
# 123620  C_ID_21d56d950c  1.001854
# 123621  C_ID_6c46fc5a9d -2.995060
# 123622  C_ID_87e7979a5f  0.096973
#
# [123623 rows x 2 columns]

# %%
test
# Out:
#         first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0                     1978  C_ID_0ab67a22ab          3          3          1
# 1                     1888  C_ID_130fd0cbdd          2          3          0
# 2                     2100  C_ID_b709037bc5          5          1          1
# 3                     2222  C_ID_d27d835a9f          2          1          0
# 4                     1491  C_ID_2b5e3df5c2          5          1          1
# ...                    ...              ...        ...        ...        ...
# 123618                2161  C_ID_7a239d2eda          2          2          0
# 123619                2131  C_ID_75ace375ae          3          1          1
# 123620                1766  C_ID_21d56d950c          5          1          1
# 123621                2039  C_ID_6c46fc5a9d          2          1          0
# 123622                1796  C_ID_87e7979a5f          5          1          1
#
#         elapsed_time  quarter  days_feature1  days_feature2  days_feature3  \
# 0                306        2            918            918            306
# 1                396        1            792           1188              0
# 2                184        3            920            184            184
# 3                 62        4            124             62              0
# 4                793        4           3965            793            793
# ...              ...      ...            ...            ...            ...
# 123618           123        4            246            246              0
# 123619           153        3            459            153            153
# 123620           518        3           2590            518            518
# 123621           245        2            490            245              0
# 123622           488        4           2440            488            488
#
#         ...  total_duration_min  total_duration_max  total_duration_mean  \
# 0       ...               158.0             51666.0          7779.549296
# 1       ...               308.0             54593.0          5825.022989
# 2       ...              1155.0            167706.0         54367.133333
# 3       ...               770.0             42812.0         10590.388889
# 4       ...                 0.0            847000.0         54698.353448
# ...     ...                 ...                 ...                  ...
# 123618  ...               770.0             11172.0          3575.301370
# 123619  ...               308.0             10780.0          2995.363636
# 123620  ...              2464.0            123585.0         29135.972973
# 123621  ...               486.0             34020.0          6241.794118
# 123622  ...              1155.0             62370.0          7506.953488
#
#         total_amount_month_ratio_min  total_amount_month_ratio_max  \
# 0                           0.025316                      8.278481
# 1                           0.051948                      9.207792
# 2                           0.194805                     28.285714
# 3                           0.129870                      7.220779
# 4                           0.000000                    142.857143
# ...                              ...                           ...
# 123618                      0.129870                      1.934211
# 123619                      0.051948                      1.818182
# 123620                      0.415584                     20.844156
# 123621                      0.074074                      5.185185
# 123622                      0.194805                     10.519481
#
#         total_amount_month_ratio_mean  total_duration  ratio_amount_total  \
# 0                            1.250920             330            0.045998
# 1                            0.982607             462            0.085422
# 2                            9.169697             199            0.117430
# 3                            1.793936             134            0.300996
# 4                            9.229007             464            0.154201
# ...                               ...             ...                 ...
# 123618                       0.607829             134            0.000000
# 123619                       0.505422             206            1.047847
# 123620                       4.922341             305            0.000000
# 123621                       0.953531             177            0.097719
# 123622                       1.268455             422            0.040933
#
#         ratio_amount_mean  ratio_merchant_category_nu
# 0                1.042612                    0.187500
# 1                0.740325                    0.500000
# 2                0.763294                    0.250000
# 3                0.782590                    0.555556
# 4                2.827010                    0.161290
# ...                   ...                         ...
# 123618           0.000000                    0.000000
# 123619           1.833732                    1.000000
# 123620           0.000000                    0.000000
# 123621           1.009765                    0.333333
# 123622           1.719176                    0.083333
#
# [123623 rows x 151 columns]
