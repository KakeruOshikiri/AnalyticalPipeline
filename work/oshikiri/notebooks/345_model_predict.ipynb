# %% [markdown]
# 244で調整したハイパラで回帰

# %% [markdown]
# ## 必要なライブラリのimport

# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
import pickle

# %%
# 予測したいデータの読み込み
path_test_preprp = '../../../../data/processed/test_processed_40.csv'

test = pd.read_csv(path_test_preprp)

# %% [markdown]
# ## 保存されたモデルを使って予測を行う

# %%
n_folds = 5
predictions = np.zeros(len(test))
features = [c for c in test.columns if c not in ['card_id',]]
#categorical_feats = ['feature_1','feature_2', 'feature_3','hist_merchant_category_nu','hist_merchant_category_mode','hist_city_nu','hist_city_mode','hist_state_nu','hist_state_mode','hist_category_1_mod','hist_category_2_mod','hist_category_3_mod','new_merchant_category_nu','new_merchant_category_mode','new_city_nu','new_city_mode','new_state_nu','new_state_mode','new_category_1_mod','new_category_2_mod','new_category_3_mod']


for fold_ in range(n_folds):
    # モデルを読み込む
    with open(f'../src/models/lgb_44/model_fold_{fold_}.pkl', 'rb') as f:
        clf = pickle.load(f)
    # モデルで予測を行う
    fold_predictions = clf.predict(test[features])
    # 予測結果を足し合わせる
    predictions += fold_predictions

# 平均を取る
predictions /= n_folds

# RMSEを計算する（テストデータに対して真の値がある場合）
# y_testが存在する場合に限り
if 'y_test' in locals():
    score = mean_squared_error(y_test, predictions, squared=False)
    print(f'RMSE={score}')

# %%
# 予測結果を出力する
print(predictions)
# Out:
# [-3.68880401 -0.32812981 -1.25990541 ...  0.80445832 -4.35725104
#   0.16340714]

# %% [markdown]
# ## 提出用ファイルの作成

# %%
sub_df = pd.DataFrame({"card_id":test["card_id"].values})
sub_df["target"] = predictions
sub_df.to_csv("../submit_oshikiri_45.csv", index=False)

# %%
import matplotlib.pyplot as plt
#plt.yscale('log')
plt.hist(sub_df.target, bins=100)
#plt.hist(predictions[predictions<0], bins=100)
# Out:
# (array([2.0000e+00, 1.0000e+00, 1.0000e+00, 3.0000e+00, 3.0000e+00,
#         2.0000e+00, 2.0000e+00, 0.0000e+00, 1.0000e+00, 4.0000e+00,
#         5.0000e+00, 6.0000e+00, 7.0000e+00, 2.0000e+00, 6.0000e+00,
#         8.0000e+00, 3.0000e+00, 1.1000e+01, 8.0000e+00, 1.2000e+01,
#         1.3000e+01, 8.0000e+00, 1.1000e+01, 8.0000e+00, 1.6000e+01,
#         1.8000e+01, 1.5000e+01, 1.0000e+01, 1.3000e+01, 2.0000e+01,
#         1.7000e+01, 2.0000e+01, 2.5000e+01, 2.1000e+01, 1.9000e+01,
#         2.8000e+01, 3.2000e+01, 2.7000e+01, 2.2000e+01, 3.0000e+01,
#         3.7000e+01, 3.0000e+01, 3.9000e+01, 3.3000e+01, 4.1000e+01,
#         3.3000e+01, 4.0000e+01, 4.4000e+01, 4.0000e+01, 6.2000e+01,
#         5.9000e+01, 6.4000e+01, 8.3000e+01, 9.5000e+01, 8.8000e+01,
#         1.0700e+02, 1.0300e+02, 1.0200e+02, 1.1600e+02, 1.3900e+02,
#         1.9300e+02, 1.9900e+02, 2.4700e+02, 2.9400e+02, 3.3000e+02,
#         3.8500e+02, 4.4100e+02, 5.2700e+02, 6.5200e+02, 8.1900e+02,
#         9.3100e+02, 1.2400e+03, 1.5590e+03, 1.9370e+03, 2.4790e+03,
#         3.2380e+03, 4.1640e+03, 5.5860e+03, 7.7320e+03, 1.1234e+04,
#         1.5944e+04, 1.8029e+04, 1.3550e+04, 8.8640e+03, 6.7220e+03,
#         5.5790e+03, 4.2140e+03, 2.4090e+03, 1.1420e+03, 5.7900e+02,
#         2.7400e+02, 1.4700e+02, 7.2000e+01, 4.9000e+01, 2.2000e+01,
#         1.4000e+01, 2.0000e+00, 4.0000e+00, 4.0000e+00, 1.0000e+00]),
#  array([-1.55020648e+01, -1.53130926e+01, -1.51241204e+01, -1.49351482e+01,
#         -1.47461760e+01, -1.45572038e+01, -1.43682316e+01, -1.41792594e+01,
#         -1.39902872e+01, -1.38013150e+01, -1.36123428e+01, -1.34233706e+01,
#         -1.32343984e+01, -1.30454262e+01, -1.28564540e+01, -1.26674818e+01,
#         -1.24785096e+01, -1.22895374e+01, -1.21005652e+01, -1.19115930e+01,
#         -1.17226208e+01, -1.15336486e+01, -1.13446764e+01, -1.11557042e+01,
#         -1.09667320e+01, -1.07777598e+01, -1.05887876e+01, -1.03998154e+01,
#         -1.02108432e+01, -1.00218710e+01, -9.83289880e+00, -9.64392660e+00,
#         -9.45495440e+00, -9.26598220e+00, -9.07701000e+00, -8.88803780e+00,
#         -8.69906560e+00, -8.51009340e+00, -8.32112120e+00, -8.13214900e+00,
#         -7.94317681e+00, -7.75420461e+00, -7.56523241e+00, -7.37626021e+00,
#         -7.18728801e+00, -6.99831581e+00, -6.80934361e+00, -6.62037141e+00,
#         -6.43139921e+00, -6.24242701e+00, -6.05345481e+00, -5.86448262e+00,
#         -5.67551042e+00, -5.48653822e+00, -5.29756602e+00, -5.10859382e+00,
#         -4.91962162e+00, -4.73064942e+00, -4.54167722e+00, -4.35270502e+00,
#         -4.16373282e+00, -3.97476063e+00, -3.78578843e+00, -3.59681623e+00,
#         -3.40784403e+00, -3.21887183e+00, -3.02989963e+00, -2.84092743e+00,
#         -2.65195523e+00, -2.46298303e+00, -2.27401083e+00, -2.08503863e+00,
#         -1.89606644e+00, -1.70709424e+00, -1.51812204e+00, -1.32914984e+00,
#         -1.14017764e+00, -9.51205440e-01, -7.62233241e-01, -5.73261042e-01,
#         -3.84288843e-01, -1.95316644e-01, -6.34444494e-03,  1.82627754e-01,
#          3.71599953e-01,  5.60572152e-01,  7.49544351e-01,  9.38516550e-01,
#          1.12748875e+00,  1.31646095e+00,  1.50543315e+00,  1.69440535e+00,
#          1.88337755e+00,  2.07234974e+00,  2.26132194e+00,  2.45029414e+00,
#          2.63926634e+00,  2.82823854e+00,  3.01721074e+00,  3.20618294e+00,
#          3.39515514e+00]),
#  <BarContainer object of 100 artists>)

# %%
sub_df
# Out:
#                 card_id    target
# 0       C_ID_0ab67a22ab -2.072153
# 1       C_ID_130fd0cbdd -0.191818
# 2       C_ID_b709037bc5 -0.591274
# 3       C_ID_d27d835a9f -0.176060
# 4       C_ID_2b5e3df5c2 -0.980048
# ...                 ...       ...
# 123618  C_ID_7a239d2eda  0.800503
# 123619  C_ID_75ace375ae -0.307557
# 123620  C_ID_21d56d950c  1.001854
# 123621  C_ID_6c46fc5a9d -2.995060
# 123622  C_ID_87e7979a5f  0.096973
#
# [123623 rows x 2 columns]

# %%
test
# Out:
#         first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0                     1978  C_ID_0ab67a22ab          3          3          1
# 1                     1888  C_ID_130fd0cbdd          2          3          0
# 2                     2100  C_ID_b709037bc5          5          1          1
# 3                     2222  C_ID_d27d835a9f          2          1          0
# 4                     1491  C_ID_2b5e3df5c2          5          1          1
# ...                    ...              ...        ...        ...        ...
# 123618                2161  C_ID_7a239d2eda          2          2          0
# 123619                2131  C_ID_75ace375ae          3          1          1
# 123620                1766  C_ID_21d56d950c          5          1          1
# 123621                2039  C_ID_6c46fc5a9d          2          1          0
# 123622                1796  C_ID_87e7979a5f          5          1          1
#
#         elapsed_time  quarter  days_feature1  days_feature2  days_feature3  \
# 0                306        2            918            918            306
# 1                396        1            792           1188              0
# 2                184        3            920            184            184
# 3                 62        4            124             62              0
# 4                793        4           3965            793            793
# ...              ...      ...            ...            ...            ...
# 123618           123        4            246            246              0
# 123619           153        3            459            153            153
# 123620           518        3           2590            518            518
# 123621           245        2            490            245              0
# 123622           488        4           2440            488            488
#
#         ...  total_duration_min  total_duration_max  total_duration_mean  \
# 0       ...               158.0             51666.0          7779.549296
# 1       ...               308.0             54593.0          5825.022989
# 2       ...              1155.0            167706.0         54367.133333
# 3       ...               770.0             42812.0         10590.388889
# 4       ...                 0.0            847000.0         54698.353448
# ...     ...                 ...                 ...                  ...
# 123618  ...               770.0             11172.0          3575.301370
# 123619  ...               308.0             10780.0          2995.363636
# 123620  ...              2464.0            123585.0         29135.972973
# 123621  ...               486.0             34020.0          6241.794118
# 123622  ...              1155.0             62370.0          7506.953488
#
#         total_amount_month_ratio_min  total_amount_month_ratio_max  \
# 0                           0.025316                      8.278481
# 1                           0.051948                      9.207792
# 2                           0.194805                     28.285714
# 3                           0.129870                      7.220779
# 4                           0.000000                    142.857143
# ...                              ...                           ...
# 123618                      0.129870                      1.934211
# 123619                      0.051948                      1.818182
# 123620                      0.415584                     20.844156
# 123621                      0.074074                      5.185185
# 123622                      0.194805                     10.519481
#
#         total_amount_month_ratio_mean  total_duration  ratio_amount_total  \
# 0                            1.250920             330            0.045998
# 1                            0.982607             462            0.085422
# 2                            9.169697             199            0.117430
# 3                            1.793936             134            0.300996
# 4                            9.229007             464            0.154201
# ...                               ...             ...                 ...
# 123618                       0.607829             134            0.000000
# 123619                       0.505422             206            1.047847
# 123620                       4.922341             305            0.000000
# 123621                       0.953531             177            0.097719
# 123622                       1.268455             422            0.040933
#
#         ratio_amount_mean  ratio_merchant_category_nu
# 0                1.042612                    0.187500
# 1                0.740325                    0.500000
# 2                0.763294                    0.250000
# 3                0.782590                    0.555556
# 4                2.827010                    0.161290
# ...                   ...                         ...
# 123618           0.000000                    0.000000
# 123619           1.833732                    1.000000
# 123620           0.000000                    0.000000
# 123621           1.009765                    0.333333
# 123622           1.719176                    0.083333
#
# [123623 rows x 151 columns]
