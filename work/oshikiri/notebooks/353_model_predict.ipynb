# %% [markdown]
# 253

# %% [markdown]
# ## 必要なライブラリのimport

# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
import pickle

pd.set_option('display.max_columns', 500)

# %%
# 予測したいデータの読み込み

path_test = '../../../../data/extornal/test_processed_clv&churn.csv'

test = pd.read_csv(path_test)

# 特徴量の選択
features = pd.read_csv('../../../../data/processed/features_52.csv')

# %%
selected_columns = features['feature'].tolist()
selected_columns.insert(0,'card_id')
test = test[selected_columns]

# %% [markdown]
# ## 保存されたモデルを使って予測を行う

# %%
n_folds = 5
predictions = np.zeros(len(test))
features = [c for c in test.columns if c not in ['card_id',]]
#categorical_feats = ['feature_1','feature_2', 'feature_3','hist_merchant_category_nu','hist_merchant_category_mode','hist_city_nu','hist_city_mode','hist_state_nu','hist_state_mode','hist_category_1_mod','hist_category_2_mod','hist_category_3_mod','new_merchant_category_nu','new_merchant_category_mode','new_city_nu','new_city_mode','new_state_nu','new_state_mode','new_category_1_mod','new_category_2_mod','new_category_3_mod']


for fold_ in range(n_folds):
    # モデルを読み込む
    with open(f'../src/models/lgb_53/model_fold_{fold_}.pkl', 'rb') as f:
        clf = pickle.load(f)
    # モデルで予測を行う
    fold_predictions = clf.predict(test[features])
    # 予測結果を足し合わせる
    predictions += fold_predictions

# 平均を取る
predictions /= n_folds

# RMSEを計算する（テストデータに対して真の値がある場合）
# y_testが存在する場合に限り
if 'y_test' in locals():
    score = mean_squared_error(y_test, predictions, squared=False)
    print(f'RMSE={score}')

# %%
# 予測結果を出力する
print(predictions)
# Out:
# [-3.74570162 -0.34236467 -1.3296341  ...  0.8717368  -4.35250363
#   0.13175841]

# %% [markdown]
# ## 提出用ファイルの作成

# %%
sub_df = pd.DataFrame({"card_id":test["card_id"].values})
sub_df["target"] = predictions
sub_df.to_csv("../submit_oshikiri_53.csv", index=False)

# %%
import matplotlib.pyplot as plt
#plt.yscale('log')
plt.hist(sub_df.target, bins=100)
#plt.hist(predictions[predictions<0], bins=100)
# Out:
# (array([2.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 4.0000e+00,
#         2.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 2.0000e+00,
#         1.0000e+00, 3.0000e+00, 5.0000e+00, 2.0000e+00, 3.0000e+00,
#         6.0000e+00, 5.0000e+00, 9.0000e+00, 9.0000e+00, 9.0000e+00,
#         1.2000e+01, 1.2000e+01, 1.1000e+01, 8.0000e+00, 1.0000e+01,
#         1.0000e+01, 1.7000e+01, 1.4000e+01, 1.6000e+01, 7.0000e+00,
#         2.3000e+01, 1.5000e+01, 1.7000e+01, 1.8000e+01, 2.2000e+01,
#         2.3000e+01, 2.7000e+01, 2.3000e+01, 1.9000e+01, 2.9000e+01,
#         3.7000e+01, 2.3000e+01, 4.1000e+01, 3.4000e+01, 4.1000e+01,
#         3.1000e+01, 3.2000e+01, 4.3000e+01, 3.6000e+01, 4.6000e+01,
#         6.5000e+01, 6.7000e+01, 6.8000e+01, 6.1000e+01, 8.4000e+01,
#         1.0000e+02, 8.6000e+01, 1.1400e+02, 1.0200e+02, 1.3400e+02,
#         1.5500e+02, 1.8700e+02, 2.2400e+02, 2.5300e+02, 2.7300e+02,
#         3.1400e+02, 4.4000e+02, 4.7200e+02, 6.0400e+02, 6.7200e+02,
#         8.8400e+02, 1.0760e+03, 1.4200e+03, 1.7980e+03, 2.2230e+03,
#         2.8550e+03, 3.7960e+03, 5.1420e+03, 6.9130e+03, 9.8100e+03,
#         1.4897e+04, 1.8959e+04, 1.5985e+04, 9.9700e+03, 7.3660e+03,
#         5.8070e+03, 4.3440e+03, 2.6000e+03, 1.2580e+03, 6.0900e+02,
#         3.2800e+02, 1.5600e+02, 9.2000e+01, 4.6000e+01, 2.2000e+01,
#         1.3000e+01, 8.0000e+00, 2.0000e+00, 2.0000e+00, 2.0000e+00]),
#  array([-16.18135108, -15.98475116, -15.78815124, -15.59155132,
#         -15.3949514 , -15.19835147, -15.00175155, -14.80515163,
#         -14.60855171, -14.41195179, -14.21535186, -14.01875194,
#         -13.82215202, -13.6255521 , -13.42895217, -13.23235225,
#         -13.03575233, -12.83915241, -12.64255249, -12.44595256,
#         -12.24935264, -12.05275272, -11.8561528 , -11.65955288,
#         -11.46295295, -11.26635303, -11.06975311, -10.87315319,
#         -10.67655327, -10.47995334, -10.28335342, -10.0867535 ,
#          -9.89015358,  -9.69355366,  -9.49695373,  -9.30035381,
#          -9.10375389,  -8.90715397,  -8.71055405,  -8.51395412,
#          -8.3173542 ,  -8.12075428,  -7.92415436,  -7.72755443,
#          -7.53095451,  -7.33435459,  -7.13775467,  -6.94115475,
#          -6.74455482,  -6.5479549 ,  -6.35135498,  -6.15475506,
#          -5.95815514,  -5.76155521,  -5.56495529,  -5.36835537,
#          -5.17175545,  -4.97515553,  -4.7785556 ,  -4.58195568,
#          -4.38535576,  -4.18875584,  -3.99215592,  -3.79555599,
#          -3.59895607,  -3.40235615,  -3.20575623,  -3.00915631,
#          -2.81255638,  -2.61595646,  -2.41935654,  -2.22275662,
#          -2.02615669,  -1.82955677,  -1.63295685,  -1.43635693,
#          -1.23975701,  -1.04315708,  -0.84655716,  -0.64995724,
#          -0.45335732,  -0.2567574 ,  -0.06015747,   0.13644245,
#           0.33304237,   0.52964229,   0.72624221,   0.92284214,
#           1.11944206,   1.31604198,   1.5126419 ,   1.70924182,
#           1.90584175,   2.10244167,   2.29904159,   2.49564151,
#           2.69224143,   2.88884136,   3.08544128,   3.2820412 ,
#           3.47864112]),
#  <BarContainer object of 100 artists>)

# %%
sub_df
# Out:
#                 card_id    target
# 0       C_ID_0ab67a22ab -2.072153
# 1       C_ID_130fd0cbdd -0.191818
# 2       C_ID_b709037bc5 -0.591274
# 3       C_ID_d27d835a9f -0.176060
# 4       C_ID_2b5e3df5c2 -0.980048
# ...                 ...       ...
# 123618  C_ID_7a239d2eda  0.800503
# 123619  C_ID_75ace375ae -0.307557
# 123620  C_ID_21d56d950c  1.001854
# 123621  C_ID_6c46fc5a9d -2.995060
# 123622  C_ID_87e7979a5f  0.096973
#
# [123623 rows x 2 columns]

# %%
test
# Out:
#         first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0                     1978  C_ID_0ab67a22ab          3          3          1
# 1                     1888  C_ID_130fd0cbdd          2          3          0
# 2                     2100  C_ID_b709037bc5          5          1          1
# 3                     2222  C_ID_d27d835a9f          2          1          0
# 4                     1491  C_ID_2b5e3df5c2          5          1          1
# ...                    ...              ...        ...        ...        ...
# 123618                2161  C_ID_7a239d2eda          2          2          0
# 123619                2131  C_ID_75ace375ae          3          1          1
# 123620                1766  C_ID_21d56d950c          5          1          1
# 123621                2039  C_ID_6c46fc5a9d          2          1          0
# 123622                1796  C_ID_87e7979a5f          5          1          1
#
#         elapsed_time  quarter  days_feature1  days_feature2  days_feature3  \
# 0                306        2            918            918            306
# 1                396        1            792           1188              0
# 2                184        3            920            184            184
# 3                 62        4            124             62              0
# 4                793        4           3965            793            793
# ...              ...      ...            ...            ...            ...
# 123618           123        4            246            246              0
# 123619           153        3            459            153            153
# 123620           518        3           2590            518            518
# 123621           245        2            490            245              0
# 123622           488        4           2440            488            488
#
#         ...  total_duration_min  total_duration_max  total_duration_mean  \
# 0       ...               158.0             51666.0          7779.549296
# 1       ...               308.0             54593.0          5825.022989
# 2       ...              1155.0            167706.0         54367.133333
# 3       ...               770.0             42812.0         10590.388889
# 4       ...                 0.0            847000.0         54698.353448
# ...     ...                 ...                 ...                  ...
# 123618  ...               770.0             11172.0          3575.301370
# 123619  ...               308.0             10780.0          2995.363636
# 123620  ...              2464.0            123585.0         29135.972973
# 123621  ...               486.0             34020.0          6241.794118
# 123622  ...              1155.0             62370.0          7506.953488
#
#         total_amount_month_ratio_min  total_amount_month_ratio_max  \
# 0                           0.025316                      8.278481
# 1                           0.051948                      9.207792
# 2                           0.194805                     28.285714
# 3                           0.129870                      7.220779
# 4                           0.000000                    142.857143
# ...                              ...                           ...
# 123618                      0.129870                      1.934211
# 123619                      0.051948                      1.818182
# 123620                      0.415584                     20.844156
# 123621                      0.074074                      5.185185
# 123622                      0.194805                     10.519481
#
#         total_amount_month_ratio_mean  total_duration  ratio_amount_total  \
# 0                            1.250920             330            0.045998
# 1                            0.982607             462            0.085422
# 2                            9.169697             199            0.117430
# 3                            1.793936             134            0.300996
# 4                            9.229007             464            0.154201
# ...                               ...             ...                 ...
# 123618                       0.607829             134            0.000000
# 123619                       0.505422             206            1.047847
# 123620                       4.922341             305            0.000000
# 123621                       0.953531             177            0.097719
# 123622                       1.268455             422            0.040933
#
#         ratio_amount_mean  ratio_merchant_category_nu
# 0                1.042612                    0.187500
# 1                0.740325                    0.500000
# 2                0.763294                    0.250000
# 3                0.782590                    0.555556
# 4                2.827010                    0.161290
# ...                   ...                         ...
# 123618           0.000000                    0.000000
# 123619           1.833732                    1.000000
# 123620           0.000000                    0.000000
# 123621           1.009765                    0.333333
# 123622           1.719176                    0.083333
#
# [123623 rows x 151 columns]
