# %% [markdown]
# 251

# %% [markdown]
# ## 必要なライブラリのimport

# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
import pickle

# %%
# 予測したいデータの読み込み

path_test = '../../../../data/extornal/test_processed_clv.csv'

test = pd.read_csv(path_test)

# 特徴量の選択
features = pd.read_csv('../../../../data/processed/features_51.csv')

selected_columns = features['feature'].tolist()
selected_columns.insert(0,'card_id')
test = test[selected_columns]

# %%
test
# Out:
#                 card_id  elapsed_time  auth_state_id_nunique  \
# 0       C_ID_0ab67a22ab           306                      3
# 1       C_ID_130fd0cbdd           396                      3
# 2       C_ID_b709037bc5           184                      4
# 3       C_ID_d27d835a9f            62                      1
# 4       C_ID_2b5e3df5c2           793                      3
# ...                 ...           ...                    ...
# 123618  C_ID_7a239d2eda           123                      2
# 123619  C_ID_75ace375ae           153                      2
# 123620  C_ID_21d56d950c           518                      3
# 123621  C_ID_6c46fc5a9d           245                      2
# 123622  C_ID_87e7979a5f           488                      3
#
#         auth_category_2_5.0_mean  feature_var  installments_count_std  \
# 0                       0.000000     1.154701                2.472066
# 1                       0.000000     1.527525                6.911343
# 2                       0.777778     2.309401                1.095445
# 3                       0.000000     1.000000                6.506407
# 4                       0.000000     2.309401                5.753642
# ...                          ...          ...                     ...
# 123618                  0.000000     1.154701                4.000000
# 123619                  0.142857     1.154701                0.894427
# 123620                  0.888889     2.309401                3.184785
# 123621                  0.000000     1.000000                3.209361
# 123622                  0.000000     2.309401                1.568929
#
#         total_state_nu  hist_ratio_Yes  new_day_nu  hist_duration_mean  ...  \
# 0                    3        0.647059         3.0         7777.191176  ...
# 1                    3        0.987179         7.0         5987.961538  ...
# 2                    5        0.692308         2.0        56133.000000  ...
# 3                    3        1.000000         8.0        11295.307692  ...
# 4                    4        0.790909         5.0        49982.781818  ...
# ...                ...             ...         ...                 ...  ...
# 123618               2        0.958904         NaN         3575.383562  ...
# 123619               2        1.000000         3.0         2299.000000  ...
# 123620               3        0.972973         NaN        29135.972973  ...
# 123621               3        0.693548         5.0         6247.016129  ...
# 123622               3        1.000000         1.0         7390.714286  ...
#
#         hist_date_max         clv  purchase_amount_sum_mean  \
# 0                 362  194.320362                 357.00000
# 1                 413  525.640587                1009.16670
# 2                 397  252.455060                 775.80000
# 3                 415  690.123914                1271.33340
# 4                 422  685.082876                5023.78560
# ...               ...         ...                       ...
# 123618            416    0.006709                 658.60000
# 123619            389  146.618757                  41.80000
# 123620            412  271.435382                1895.57140
# 123621            302    0.000059                 710.20000
# 123622            423  222.952686                 287.92856
#
#         new_purchase_month_mean  history_month_diff_mean  total_date_max  \
# 0                      2.000000                78.916667             423
# 1                      3.444444                77.000000             474
# 2                      3.000000                77.000000             436
# 3                      3.300000                      NaN             471
# 4                      3.166667                77.000000             466
# ...                         ...                      ...             ...
# 123618                      NaN                77.000000             416
# 123619                 3.250000                      NaN             472
# 123620                      NaN                77.000000             412
# 123621                11.000000                81.000000             328
# 123622                 3.000000                      NaN             429
#
#         auth_purchase_date_max  ratio_merchant_category_nu  \
# 0                 1.514510e+09                    0.187500
# 1                 1.518989e+09                    0.500000
# 2                 1.517598e+09                    0.250000
# 3                 1.519127e+09                    0.555556
# 4                 1.519728e+09                    0.161290
# ...                        ...                         ...
# 123618            1.519213e+09                         NaN
# 123619            1.516884e+09                    1.000000
# 123620            1.518882e+09                         NaN
# 123621            1.509376e+09                    0.333333
# 123622            1.519807e+09                    0.083333
#
#         auth_month_diff_mean  new_purchase_amount_sum
# 0                  78.954545                    309.0
# 1                  77.025974                    518.0
# 2                  77.000000                   1114.0
# 3                  77.000000                   1147.0
# 4                  76.977011                  11011.0
# ...                      ...                      ...
# 123618             76.785714                      NaN
# 123619             77.000000                    219.0
# 123620             76.833333                      NaN
# 123621             80.930233                    467.0
# 123622             77.023810                    165.0
#
# [123623 rows x 236 columns]

# %% [markdown]
# ## 保存されたモデルを使って予測を行う

# %%
n_folds = 5
predictions = np.zeros(len(test))
features = [c for c in test.columns if c not in ['card_id',]]
#categorical_feats = ['feature_1','feature_2', 'feature_3','hist_merchant_category_nu','hist_merchant_category_mode','hist_city_nu','hist_city_mode','hist_state_nu','hist_state_mode','hist_category_1_mod','hist_category_2_mod','hist_category_3_mod','new_merchant_category_nu','new_merchant_category_mode','new_city_nu','new_city_mode','new_state_nu','new_state_mode','new_category_1_mod','new_category_2_mod','new_category_3_mod']


for fold_ in range(n_folds):
    # モデルを読み込む
    with open(f'../src/models/lgb_51/model_fold_{fold_}.pkl', 'rb') as f:
        clf = pickle.load(f)
    # モデルで予測を行う
    fold_predictions = clf.predict(test[features])
    # 予測結果を足し合わせる
    predictions += fold_predictions

# 平均を取る
predictions /= n_folds

# RMSEを計算する（テストデータに対して真の値がある場合）
# y_testが存在する場合に限り
if 'y_test' in locals():
    score = mean_squared_error(y_test, predictions, squared=False)
    print(f'RMSE={score}')

# %%
# 予測結果を出力する
print(predictions)
# Out:
# [-3.73537925 -0.31887157 -1.27990633 ...  0.89266978 -4.58171523
#   0.12573991]

# %% [markdown]
# ## 提出用ファイルの作成

# %%
sub_df = pd.DataFrame({"card_id":test["card_id"].values})
sub_df["target"] = predictions
sub_df.to_csv("../submit_oshikiri_51.csv", index=False)

# %%
import matplotlib.pyplot as plt
#plt.yscale('log')
plt.hist(sub_df.target, bins=100)
#plt.hist(predictions[predictions<0], bins=100)
# Out:
# (array([1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 5.0000e+00,
#         2.0000e+00, 0.0000e+00, 2.0000e+00, 1.0000e+00, 3.0000e+00,
#         3.0000e+00, 1.0000e+00, 3.0000e+00, 4.0000e+00, 2.0000e+00,
#         9.0000e+00, 7.0000e+00, 5.0000e+00, 4.0000e+00, 1.4000e+01,
#         1.1000e+01, 1.4000e+01, 8.0000e+00, 9.0000e+00, 1.4000e+01,
#         1.5000e+01, 1.1000e+01, 1.5000e+01, 1.0000e+01, 1.2000e+01,
#         1.9000e+01, 1.6000e+01, 1.7000e+01, 1.7000e+01, 1.7000e+01,
#         3.1000e+01, 2.2000e+01, 3.0000e+01, 1.8000e+01, 2.9000e+01,
#         3.1000e+01, 3.3000e+01, 3.5000e+01, 4.3000e+01, 2.8000e+01,
#         3.2000e+01, 2.9000e+01, 4.1000e+01, 3.5000e+01, 6.1000e+01,
#         5.1000e+01, 5.7000e+01, 6.3000e+01, 7.8000e+01, 8.9000e+01,
#         8.3000e+01, 9.5000e+01, 1.0500e+02, 1.1500e+02, 1.0700e+02,
#         1.4300e+02, 1.8200e+02, 2.3300e+02, 2.2500e+02, 2.7000e+02,
#         3.1200e+02, 4.0600e+02, 4.6300e+02, 5.7100e+02, 6.7300e+02,
#         8.2300e+02, 9.8900e+02, 1.3180e+03, 1.6770e+03, 2.0940e+03,
#         2.7010e+03, 3.4930e+03, 4.6510e+03, 6.1590e+03, 8.7260e+03,
#         1.2726e+04, 1.7820e+04, 1.7855e+04, 1.1831e+04, 8.0260e+03,
#         6.1220e+03, 4.9360e+03, 3.1920e+03, 1.6860e+03, 8.2900e+02,
#         4.2400e+02, 2.2700e+02, 1.0300e+02, 6.7000e+01, 2.4000e+01,
#         1.6000e+01, 9.0000e+00, 2.0000e+00, 3.0000e+00, 1.0000e+00]),
#  array([-16.16220581, -15.96666259, -15.77111936, -15.57557613,
#         -15.38003291, -15.18448968, -14.98894646, -14.79340323,
#         -14.59786001, -14.40231678, -14.20677356, -14.01123033,
#         -13.81568711, -13.62014388, -13.42460066, -13.22905743,
#         -13.03351421, -12.83797098, -12.64242775, -12.44688453,
#         -12.2513413 , -12.05579808, -11.86025485, -11.66471163,
#         -11.4691684 , -11.27362518, -11.07808195, -10.88253873,
#         -10.6869955 , -10.49145228, -10.29590905, -10.10036582,
#          -9.9048226 ,  -9.70927937,  -9.51373615,  -9.31819292,
#          -9.1226497 ,  -8.92710647,  -8.73156325,  -8.53602002,
#          -8.3404768 ,  -8.14493357,  -7.94939035,  -7.75384712,
#          -7.5583039 ,  -7.36276067,  -7.16721744,  -6.97167422,
#          -6.77613099,  -6.58058777,  -6.38504454,  -6.18950132,
#          -5.99395809,  -5.79841487,  -5.60287164,  -5.40732842,
#          -5.21178519,  -5.01624197,  -4.82069874,  -4.62515552,
#          -4.42961229,  -4.23406906,  -4.03852584,  -3.84298261,
#          -3.64743939,  -3.45189616,  -3.25635294,  -3.06080971,
#          -2.86526649,  -2.66972326,  -2.47418004,  -2.27863681,
#          -2.08309359,  -1.88755036,  -1.69200713,  -1.49646391,
#          -1.30092068,  -1.10537746,  -0.90983423,  -0.71429101,
#          -0.51874778,  -0.32320456,  -0.12766133,   0.06788189,
#           0.26342512,   0.45896834,   0.65451157,   0.85005479,
#           1.04559802,   1.24114125,   1.43668447,   1.6322277 ,
#           1.82777092,   2.02331415,   2.21885737,   2.4144006 ,
#           2.60994382,   2.80548705,   3.00103027,   3.1965735 ,
#           3.39211672]),
#  <BarContainer object of 100 artists>)

# %%
sub_df
# Out:
#                 card_id    target
# 0       C_ID_0ab67a22ab -2.072153
# 1       C_ID_130fd0cbdd -0.191818
# 2       C_ID_b709037bc5 -0.591274
# 3       C_ID_d27d835a9f -0.176060
# 4       C_ID_2b5e3df5c2 -0.980048
# ...                 ...       ...
# 123618  C_ID_7a239d2eda  0.800503
# 123619  C_ID_75ace375ae -0.307557
# 123620  C_ID_21d56d950c  1.001854
# 123621  C_ID_6c46fc5a9d -2.995060
# 123622  C_ID_87e7979a5f  0.096973
#
# [123623 rows x 2 columns]

# %%
test
# Out:
#         first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0                     1978  C_ID_0ab67a22ab          3          3          1
# 1                     1888  C_ID_130fd0cbdd          2          3          0
# 2                     2100  C_ID_b709037bc5          5          1          1
# 3                     2222  C_ID_d27d835a9f          2          1          0
# 4                     1491  C_ID_2b5e3df5c2          5          1          1
# ...                    ...              ...        ...        ...        ...
# 123618                2161  C_ID_7a239d2eda          2          2          0
# 123619                2131  C_ID_75ace375ae          3          1          1
# 123620                1766  C_ID_21d56d950c          5          1          1
# 123621                2039  C_ID_6c46fc5a9d          2          1          0
# 123622                1796  C_ID_87e7979a5f          5          1          1
#
#         elapsed_time  quarter  days_feature1  days_feature2  days_feature3  \
# 0                306        2            918            918            306
# 1                396        1            792           1188              0
# 2                184        3            920            184            184
# 3                 62        4            124             62              0
# 4                793        4           3965            793            793
# ...              ...      ...            ...            ...            ...
# 123618           123        4            246            246              0
# 123619           153        3            459            153            153
# 123620           518        3           2590            518            518
# 123621           245        2            490            245              0
# 123622           488        4           2440            488            488
#
#         ...  total_duration_min  total_duration_max  total_duration_mean  \
# 0       ...               158.0             51666.0          7779.549296
# 1       ...               308.0             54593.0          5825.022989
# 2       ...              1155.0            167706.0         54367.133333
# 3       ...               770.0             42812.0         10590.388889
# 4       ...                 0.0            847000.0         54698.353448
# ...     ...                 ...                 ...                  ...
# 123618  ...               770.0             11172.0          3575.301370
# 123619  ...               308.0             10780.0          2995.363636
# 123620  ...              2464.0            123585.0         29135.972973
# 123621  ...               486.0             34020.0          6241.794118
# 123622  ...              1155.0             62370.0          7506.953488
#
#         total_amount_month_ratio_min  total_amount_month_ratio_max  \
# 0                           0.025316                      8.278481
# 1                           0.051948                      9.207792
# 2                           0.194805                     28.285714
# 3                           0.129870                      7.220779
# 4                           0.000000                    142.857143
# ...                              ...                           ...
# 123618                      0.129870                      1.934211
# 123619                      0.051948                      1.818182
# 123620                      0.415584                     20.844156
# 123621                      0.074074                      5.185185
# 123622                      0.194805                     10.519481
#
#         total_amount_month_ratio_mean  total_duration  ratio_amount_total  \
# 0                            1.250920             330            0.045998
# 1                            0.982607             462            0.085422
# 2                            9.169697             199            0.117430
# 3                            1.793936             134            0.300996
# 4                            9.229007             464            0.154201
# ...                               ...             ...                 ...
# 123618                       0.607829             134            0.000000
# 123619                       0.505422             206            1.047847
# 123620                       4.922341             305            0.000000
# 123621                       0.953531             177            0.097719
# 123622                       1.268455             422            0.040933
#
#         ratio_amount_mean  ratio_merchant_category_nu
# 0                1.042612                    0.187500
# 1                0.740325                    0.500000
# 2                0.763294                    0.250000
# 3                0.782590                    0.555556
# 4                2.827010                    0.161290
# ...                   ...                         ...
# 123618           0.000000                    0.000000
# 123619           1.833732                    1.000000
# 123620           0.000000                    0.000000
# 123621           1.009765                    0.333333
# 123622           1.719176                    0.083333
#
# [123623 rows x 151 columns]
