# %%
import warnings
import time
import sys
import datetime
import pickle
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error

warnings.simplefilter(action='ignore', category=FutureWarning)
pd.set_option('display.max_columns', 500)

# %matplotlib inline

# %%
# データの読み込み
path_train_prepro = '../../../../data/processed/train_processed_0618.csv'
train = pd.read_csv(path_train_prepro)
train.columns
# Out:
# Index(['first_active_month', 'card_id', 'feature_1', 'feature_2', 'feature_3',
#        'target', 'elapsed_time', 'hist_frequency', 'hist_amount_total',
#        'hist_amount_mean', 'hist_merchant_category_nu',
#        'hist_merchant_category_mode', 'hist_city_nu', 'hist_city_mode',
#        'hist_state_nu', 'hist_state_mode', 'hist_date_min', 'hist_date_max',
#        'hist_installments_mean', 'hist_installments_max',
#        'hist_installments_min', 'hist_month_lag_mean', 'hist_month_lag_max',
#        'hist_month_lag_min', 'hist_category_1_mod', 'hist_category_2_mod',
#        'hist_category_3_mod', 'hist_ratio_No', 'hist_ratio_Yes',
#        'hist_count_No', 'hist_count_Yes', 'hist_duration'],
#       dtype='object')

# %%
train.drop(columns={'first_active_month','card_id','hist_date_min','hist_date_max'}).corr()
# Out:
#                              feature_1  feature_2  feature_3    target  \
# feature_1                     1.000000  -0.130969   0.583092 -0.014251
# feature_2                    -0.130969   1.000000   0.060925 -0.006242
# feature_3                     0.583092   0.060925   1.000000 -0.008125
# target                       -0.014251  -0.006242  -0.008125  1.000000
# elapsed_time                  0.117144   0.158150   0.196046 -0.050453
# hist_frequency                0.016334  -0.001444  -0.019213 -0.011640
# hist_amount_total            -0.000015  -0.002228   0.001853  0.000154
# hist_amount_mean             -0.000154  -0.002277   0.001860  0.000295
# hist_merchant_category_nu    -0.001235  -0.022814  -0.064716 -0.013517
# hist_merchant_category_mode  -0.062191   0.009207  -0.030210 -0.011544
# hist_city_nu                  0.035548  -0.068914  -0.056220 -0.006320
# hist_city_mode               -0.002169   0.037559   0.056173  0.010941
# hist_state_nu                 0.000680  -0.032445  -0.081851 -0.011204
# hist_state_mode              -0.008908   0.049198   0.043557  0.007871
# hist_installments_mean        0.038405  -0.149567  -0.198370 -0.013910
# hist_installments_max         0.006874  -0.039360  -0.048545 -0.006200
# hist_installments_min         0.022564  -0.027329   0.010398 -0.039120
# hist_month_lag_mean          -0.092372  -0.082886  -0.098449 -0.004000
# hist_month_lag_max           -0.013975  -0.047471  -0.034171 -0.017872
# hist_month_lag_min           -0.100992  -0.087052  -0.111970  0.001677
# hist_category_1_mod           0.001340  -0.064085  -0.090561 -0.022791
# hist_category_2_mod          -0.007831   0.102278   0.023708  0.011265
# hist_category_3_mod           0.015557  -0.202244  -0.282022 -0.019240
# hist_ratio_No                 0.052071   0.012033   0.127352 -0.042127
# hist_ratio_Yes               -0.052071  -0.012033  -0.127352  0.042127
# hist_count_No                 0.080817   0.015293   0.096593 -0.048008
# hist_count_Yes                0.007531  -0.003355  -0.031827 -0.006516
# hist_duration                 0.098268   0.079725   0.105359 -0.007183
#
#                              elapsed_time  hist_frequency  hist_amount_total  \
# feature_1                        0.117144        0.016334          -0.000015
# feature_2                        0.158150       -0.001444          -0.002228
# feature_3                        0.196046       -0.019213           0.001853
# target                          -0.050453       -0.011640           0.000154
# elapsed_time                     1.000000        0.126030          -0.000825
# hist_frequency                   0.126030        1.000000          -0.004046
# hist_amount_total               -0.000825       -0.004046           1.000000
# hist_amount_mean                -0.000635       -0.001759           0.996139
# hist_merchant_category_nu        0.097903        0.793448          -0.004161
# hist_merchant_category_mode      0.026759       -0.014476           0.001835
# hist_city_nu                     0.034233        0.561965          -0.003418
# hist_city_mode                   0.012706        0.013258           0.002500
# hist_state_nu                   -0.000554        0.396431          -0.003604
# hist_state_mode                  0.019926        0.055679          -0.000497
# hist_installments_mean          -0.067094       -0.162168          -0.001769
# hist_installments_max           -0.011186        0.013461          -0.000411
# hist_installments_min            0.071657       -0.118709          -0.000107
# hist_month_lag_mean             -0.529314       -0.257466           0.003555
# hist_month_lag_max              -0.087346        0.122953           0.000049
# hist_month_lag_min              -0.580974       -0.324640           0.003357
# hist_category_1_mod              0.005598       -0.091496          -0.000600
# hist_category_2_mod             -0.005920        0.023020          -0.001148
# hist_category_3_mod             -0.093191       -0.142707          -0.002570
# hist_ratio_No                    0.018283       -0.149331           0.000701
# hist_ratio_Yes                  -0.018283        0.149331          -0.000701
# hist_count_No                    0.116563        0.496163          -0.001441
# hist_count_Yes                   0.118870        0.994572          -0.004092
# hist_duration                    0.572402        0.371001          -0.003459
#
#                              hist_amount_mean  hist_merchant_category_nu  \
# feature_1                           -0.000154                  -0.001235
# feature_2                           -0.002277                  -0.022814
# feature_3                            0.001860                  -0.064716
# target                               0.000295                  -0.013517
# elapsed_time                        -0.000635                   0.097903
# hist_frequency                      -0.001759                   0.793448
# hist_amount_total                    0.996139                  -0.004161
# hist_amount_mean                     1.000000                  -0.002519
# hist_merchant_category_nu           -0.002519                   1.000000
# hist_merchant_category_mode          0.001624                  -0.052626
# hist_city_nu                        -0.001927                   0.645214
# hist_city_mode                       0.002180                   0.032471
# hist_state_nu                       -0.002567                   0.508204
# hist_state_mode                     -0.000495                   0.092150
# hist_installments_mean              -0.001677                  -0.126353
# hist_installments_max               -0.000415                   0.034394
# hist_installments_min               -0.000266                  -0.231776
# hist_month_lag_mean                  0.003320                  -0.234808
# hist_month_lag_max                   0.000481                   0.149143
# hist_month_lag_min                   0.002867                  -0.308606
# hist_category_1_mod                 -0.000614                  -0.197417
# hist_category_2_mod                 -0.001581                   0.028350
# hist_category_3_mod                 -0.002137                  -0.094955
# hist_ratio_No                       -0.000208                  -0.213450
# hist_ratio_Yes                       0.000208                   0.213450
# hist_count_No                       -0.001237                   0.344081
# hist_count_Yes                      -0.001706                   0.795085
# hist_duration                       -0.002835                   0.358950
#
#                              hist_merchant_category_mode  hist_city_nu  \
# feature_1                                      -0.062191      0.035548
# feature_2                                       0.009207     -0.068914
# feature_3                                      -0.030210     -0.056220
# target                                         -0.011544     -0.006320
# elapsed_time                                    0.026759      0.034233
# hist_frequency                                 -0.014476      0.561965
# hist_amount_total                               0.001835     -0.003418
# hist_amount_mean                                0.001624     -0.001927
# hist_merchant_category_nu                      -0.052626      0.645214
# hist_merchant_category_mode                     1.000000     -0.113257
# hist_city_nu                                   -0.113257      1.000000
# hist_city_mode                                 -0.054672      0.063455
# hist_state_nu                                  -0.062192      0.729571
# hist_state_mode                                -0.102295      0.082241
# hist_installments_mean                          0.059470     -0.039598
# hist_installments_max                           0.010144      0.034840
# hist_installments_min                           0.035275     -0.136136
# hist_month_lag_mean                            -0.019771     -0.143738
# hist_month_lag_max                              0.024326      0.104391
# hist_month_lag_min                             -0.032836     -0.195201
# hist_category_1_mod                             0.201547     -0.144455
# hist_category_2_mod                            -0.047212      0.032106
# hist_category_3_mod                             0.057039      0.000577
# hist_ratio_No                                   0.085342     -0.149884
# hist_ratio_Yes                                 -0.085342      0.149884
# hist_count_No                                   0.058934      0.217384
# hist_count_Yes                                 -0.022321      0.566279
# hist_duration                                   0.036588      0.229620
#
#                              hist_city_mode  hist_state_nu  hist_state_mode  \
# feature_1                         -0.002169       0.000680        -0.008908
# feature_2                          0.037559      -0.032445         0.049198
# feature_3                          0.056173      -0.081851         0.043557
# target                             0.010941      -0.011204         0.007871
# elapsed_time                       0.012706      -0.000554         0.019926
# hist_frequency                     0.013258       0.396431         0.055679
# hist_amount_total                  0.002500      -0.003604        -0.000497
# hist_amount_mean                   0.002180      -0.002567        -0.000495
# hist_merchant_category_nu          0.032471       0.508204         0.092150
# hist_merchant_category_mode       -0.054672      -0.062192        -0.102295
# hist_city_nu                       0.063455       0.729571         0.082241
# hist_city_mode                     1.000000       0.039762         0.214210
# hist_state_nu                      0.039762       1.000000         0.099975
# hist_state_mode                    0.214210       0.099975         1.000000
# hist_installments_mean            -0.121994       0.059320        -0.165077
# hist_installments_max             -0.017452       0.050007        -0.018198
# hist_installments_min             -0.068404      -0.121091        -0.093735
# hist_month_lag_mean               -0.015104      -0.104587        -0.019051
# hist_month_lag_max                -0.011206       0.093409        -0.008312
# hist_month_lag_min                -0.017155      -0.151393        -0.019126
# hist_category_1_mod               -0.321871      -0.080511        -0.464945
# hist_category_2_mod                0.158103       0.207926         0.241326
# hist_category_3_mod               -0.127109       0.098839        -0.166751
# hist_ratio_No                     -0.054645      -0.072914        -0.084403
# hist_ratio_Yes                     0.054645       0.072914         0.084403
# hist_count_No                     -0.030222       0.183529        -0.020650
# hist_count_Yes                     0.017596       0.395857         0.061162
# hist_duration                      0.016696       0.178845         0.020943
#
#                              hist_installments_mean  hist_installments_max  \
# feature_1                                  0.038405               0.006874
# feature_2                                 -0.149567              -0.039360
# feature_3                                 -0.198370              -0.048545
# target                                    -0.013910              -0.006200
# elapsed_time                              -0.067094              -0.011186
# hist_frequency                            -0.162168               0.013461
# hist_amount_total                         -0.001769              -0.000411
# hist_amount_mean                          -0.001677              -0.000415
# hist_merchant_category_nu                 -0.126353               0.034394
# hist_merchant_category_mode                0.059470               0.010144
# hist_city_nu                              -0.039598               0.034840
# hist_city_mode                            -0.121994              -0.017452
# hist_state_nu                              0.059320               0.050007
# hist_state_mode                           -0.165077              -0.018198
# hist_installments_mean                     1.000000               0.465502
# hist_installments_max                      0.465502               1.000000
# hist_installments_min                      0.099150              -0.018778
# hist_month_lag_mean                        0.036882              -0.008956
# hist_month_lag_max                        -0.007069               0.011430
# hist_month_lag_min                         0.060384              -0.010204
# hist_category_1_mod                        0.274077               0.032216
# hist_category_2_mod                       -0.078488              -0.008035
# hist_category_3_mod                        0.783222               0.147279
# hist_ratio_No                              0.102309               0.008936
# hist_ratio_Yes                            -0.102309              -0.008936
# hist_count_No                             -0.068702               0.007653
# hist_count_Yes                            -0.162697               0.013271
# hist_duration                             -0.070339               0.012043
#
#                              hist_installments_min  hist_month_lag_mean  \
# feature_1                                 0.022564            -0.092372
# feature_2                                -0.027329            -0.082886
# feature_3                                 0.010398            -0.098449
# target                                   -0.039120            -0.004000
# elapsed_time                              0.071657            -0.529314
# hist_frequency                           -0.118709            -0.257466
# hist_amount_total                        -0.000107             0.003555
# hist_amount_mean                         -0.000266             0.003320
# hist_merchant_category_nu                -0.231776            -0.234808
# hist_merchant_category_mode               0.035275            -0.019771
# hist_city_nu                             -0.136136            -0.143738
# hist_city_mode                           -0.068404            -0.015104
# hist_state_nu                            -0.121091            -0.104587
# hist_state_mode                          -0.093735            -0.019051
# hist_installments_mean                    0.099150             0.036882
# hist_installments_max                    -0.018778            -0.008956
# hist_installments_min                     1.000000            -0.014740
# hist_month_lag_mean                      -0.014740             1.000000
# hist_month_lag_max                       -0.069380             0.289643
# hist_month_lag_min                        0.027504             0.884950
# hist_category_1_mod                       0.199353            -0.000650
# hist_category_2_mod                      -0.056898            -0.009307
# hist_category_3_mod                       0.075697             0.065798
# hist_ratio_No                             0.042609            -0.033765
# hist_ratio_Yes                           -0.042609             0.033765
# hist_count_No                            -0.037065            -0.199379
# hist_count_Yes                           -0.120681            -0.247483
# hist_duration                            -0.043467            -0.834522
#
#                              hist_month_lag_max  hist_month_lag_min  \
# feature_1                             -0.013975           -0.100992
# feature_2                             -0.047471           -0.087052
# feature_3                             -0.034171           -0.111970
# target                                -0.017872            0.001677
# elapsed_time                          -0.087346           -0.580974
# hist_frequency                         0.122953           -0.324640
# hist_amount_total                      0.000049            0.003357
# hist_amount_mean                       0.000481            0.002867
# hist_merchant_category_nu              0.149143           -0.308606
# hist_merchant_category_mode            0.024326           -0.032836
# hist_city_nu                           0.104391           -0.195201
# hist_city_mode                        -0.011206           -0.017155
# hist_state_nu                          0.093409           -0.151393
# hist_state_mode                       -0.008312           -0.019126
# hist_installments_mean                -0.007069            0.060384
# hist_installments_max                  0.011430           -0.010204
# hist_installments_min                 -0.069380            0.027504
# hist_month_lag_mean                    0.289643            0.884950
# hist_month_lag_max                     1.000000            0.116137
# hist_month_lag_min                     0.116137            1.000000
# hist_category_1_mod                    0.010002           -0.001921
# hist_category_2_mod                   -0.011213           -0.011009
# hist_category_3_mod                    0.020083            0.092427
# hist_ratio_No                         -0.042955           -0.018132
# hist_ratio_Yes                         0.042955            0.018132
# hist_count_No                          0.067208           -0.240469
# hist_count_Yes                         0.121543           -0.313363
# hist_duration                          0.059978           -0.979837
#
#                              hist_category_1_mod  hist_category_2_mod  \
# feature_1                               0.001340            -0.007831
# feature_2                              -0.064085             0.102278
# feature_3                              -0.090561             0.023708
# target                                 -0.022791             0.011265
# elapsed_time                            0.005598            -0.005920
# hist_frequency                         -0.091496             0.023020
# hist_amount_total                      -0.000600            -0.001148
# hist_amount_mean                       -0.000614            -0.001581
# hist_merchant_category_nu              -0.197417             0.028350
# hist_merchant_category_mode             0.201547            -0.047212
# hist_city_nu                           -0.144455             0.032106
# hist_city_mode                         -0.321871             0.158103
# hist_state_nu                          -0.080511             0.207926
# hist_state_mode                        -0.464945             0.241326
# hist_installments_mean                  0.274077            -0.078488
# hist_installments_max                   0.032216            -0.008035
# hist_installments_min                   0.199353            -0.056898
# hist_month_lag_mean                    -0.000650            -0.009307
# hist_month_lag_max                      0.010002            -0.011213
# hist_month_lag_min                     -0.001921            -0.011009
# hist_category_1_mod                     1.000000            -0.195299
# hist_category_2_mod                    -0.195299             1.000000
# hist_category_3_mod                     0.269315            -0.090876
# hist_ratio_No                           0.160122            -0.042891
# hist_ratio_Yes                         -0.160122             0.042891
# hist_count_No                           0.062985            -0.019057
# hist_count_Yes                         -0.103988             0.026548
# hist_duration                          -0.001838             0.010199
#
#                              hist_category_3_mod  hist_ratio_No  \
# feature_1                               0.015557       0.052071
# feature_2                              -0.202244       0.012033
# feature_3                              -0.282022       0.127352
# target                                 -0.019240      -0.042127
# elapsed_time                           -0.093191       0.018283
# hist_frequency                         -0.142707      -0.149331
# hist_amount_total                      -0.002570       0.000701
# hist_amount_mean                       -0.002137      -0.000208
# hist_merchant_category_nu              -0.094955      -0.213450
# hist_merchant_category_mode             0.057039       0.085342
# hist_city_nu                            0.000577      -0.149884
# hist_city_mode                         -0.127109      -0.054645
# hist_state_nu                           0.098839      -0.072914
# hist_state_mode                        -0.166751      -0.084403
# hist_installments_mean                  0.783222       0.102309
# hist_installments_max                   0.147279       0.008936
# hist_installments_min                   0.075697       0.042609
# hist_month_lag_mean                     0.065798      -0.033765
# hist_month_lag_max                      0.020083      -0.042955
# hist_month_lag_min                      0.092427      -0.018132
# hist_category_1_mod                     0.269315       0.160122
# hist_category_2_mod                    -0.090876      -0.042891
# hist_category_3_mod                     1.000000       0.038920
# hist_ratio_No                           0.038920       1.000000
# hist_ratio_Yes                         -0.038920      -1.000000
# hist_count_No                          -0.084131       0.457809
# hist_count_Yes                         -0.140335      -0.212267
# hist_duration                          -0.097168       0.003100
#
#                              hist_ratio_Yes  hist_count_No  hist_count_Yes  \
# feature_1                         -0.052071       0.080817        0.007531
# feature_2                         -0.012033       0.015293       -0.003355
# feature_3                         -0.127352       0.096593       -0.031827
# target                             0.042127      -0.048008       -0.006516
# elapsed_time                      -0.018283       0.116563        0.118870
# hist_frequency                     0.149331       0.496163        0.994572
# hist_amount_total                 -0.000701      -0.001441       -0.004092
# hist_amount_mean                   0.000208      -0.001237       -0.001706
# hist_merchant_category_nu          0.213450       0.344081        0.795085
# hist_merchant_category_mode       -0.085342       0.058934       -0.022321
# hist_city_nu                       0.149884       0.217384        0.566279
# hist_city_mode                     0.054645      -0.030222        0.017596
# hist_state_nu                      0.072914       0.183529        0.395857
# hist_state_mode                    0.084403      -0.020650        0.061162
# hist_installments_mean            -0.102309      -0.068702       -0.162697
# hist_installments_max             -0.008936       0.007653        0.013271
# hist_installments_min             -0.042609      -0.037065       -0.120681
# hist_month_lag_mean                0.033765      -0.199379       -0.247483
# hist_month_lag_max                 0.042955       0.067208        0.121543
# hist_month_lag_min                 0.018132      -0.240469       -0.313363
# hist_category_1_mod               -0.160122       0.062985       -0.103988
# hist_category_2_mod                0.042891      -0.019057        0.026548
# hist_category_3_mod               -0.038920      -0.084131       -0.140335
# hist_ratio_No                     -1.000000       0.457809       -0.212267
# hist_ratio_Yes                     1.000000      -0.457809        0.212267
# hist_count_No                     -0.457809       1.000000        0.403127
# hist_count_Yes                     0.212267       0.403127        1.000000
# hist_duration                     -0.003100       0.263826        0.359429
#
#                              hist_duration
# feature_1                         0.098268
# feature_2                         0.079725
# feature_3                         0.105359
# target                           -0.007183
# elapsed_time                      0.572402
# hist_frequency                    0.371001
# hist_amount_total                -0.003459
# hist_amount_mean                 -0.002835
# hist_merchant_category_nu         0.358950
# hist_merchant_category_mode       0.036588
# hist_city_nu                      0.229620
# hist_city_mode                    0.016696
# hist_state_nu                     0.178845
# hist_state_mode                   0.020943
# hist_installments_mean           -0.070339
# hist_installments_max             0.012043
# hist_installments_min            -0.043467
# hist_month_lag_mean              -0.834522
# hist_month_lag_max                0.059978
# hist_month_lag_min               -0.979837
# hist_category_1_mod              -0.001838
# hist_category_2_mod               0.010199
# hist_category_3_mod              -0.097168
# hist_ratio_No                     0.003100
# hist_ratio_Yes                   -0.003100
# hist_count_No                     0.263826
# hist_count_Yes                    0.359429
# hist_duration                     1.000000

# %%
train.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 train.corr()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: '2017-06-01'
